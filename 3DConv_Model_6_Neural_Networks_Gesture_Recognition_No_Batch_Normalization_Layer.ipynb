# %% [markdown]
# # Gesture Recognition - Model 6
# #### Conv3D Model with comprehensive preprocessing (using OpenCV library - Resize and Data augmetation with Affine transformation, Horizontal Flip, Cropping and Resizing,  Usage of Optimizer,  ReduceLROnPlateau to reduce learning rate and experimenting with various sizes of batch sizes and Epochs)
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import datetime
import os
import cv2

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.set_random_seed(30)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# In this block, you read the folder names for training and validation. We will set the initial `batch_size` here. Note that we will experimentally set the batch size in such a way that you are able to use the GPU in full capacity. Keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('./Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('./Project_data/val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator is broken down into modules. In the generator, we are going to preprocess the images as we have images of 2 different dimensions as well as create a batch of video frames.

# %%
# Parameters initialization
nb_rows = 120   # X dimension of the image
nb_cols = 120   # Y dimesnion of the image

nb_frames = 30  # lenght of the video frames
nb_channel = 3 # number of channels in images 3 for color(RGB) and 1 for Gray

# %%
# Helper function to generate a random affine transform on the iamge
def get_random_affine():
    dx, dy = np.random.randint(-1.7, 1.8, 2)
    M = np.float32([[1, 0, dx], [0, 1, dy]])
    return M

# %%
# # Function that normalises the data
# def normalize_data(data):
#     return data/127.5-1

# %%
# Function that initializes all the batch image data and labels
def initialize_batch_data(batch_size):
    batch_data = np.zeros((batch_size, nb_frames, nb_rows, nb_cols, nb_channel)) 
    batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
    return batch_data, batch_labels

# %%
def process_batch_images(source_path, folder_list, batch_num, batch_size, t,validation):
    
    batch_data,batch_labels = initialize_batch_data(batch_size)
    
    # For building an augumented batch data with affine transformation
    batch_data_aug,batch_labels_aug = initialize_batch_data(batch_size)
    
    # For building an augmented batch data with horizontal flip
    batch_data_flip,batch_labels_flip = initialize_batch_data(batch_size)
    
    #create a list of image numbers you want to use for a particular video using full frames
    img_idx = [x for x in range(0, nb_frames)] 

    for folder in range(batch_size): # iterate over the batch_size
        # read all the images in the folder
        imgs = sorted(os.listdir(source_path+'/'+ t[folder + (batch_num*batch_size)].split(';')[0])) 
        # Generating a random affine to be used in image transformation for buidling agumented data set
        M = get_random_affine()
        
        #  Iterate over the frames/images of a folder to read them in
        for idx, item in enumerate(img_idx): 
            image = cv2.imread(source_path+'/'+ t[folder + (batch_num*batch_size)].strip().split(';')[0]+'/'+imgs[item], cv2.IMREAD_COLOR)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            # Cropping non symmetric frames
            if image.shape[0] != image.shape[1]:
                image=image[0:120,20:140]
            
            #crop the images and resize them. Note that the images are of 2 different shape 
            #and the conv3D will throw error if the inputs in a batch have different shapes   
            resized = cv2.resize(image, (nb_rows,nb_cols), interpolation = cv2.INTER_AREA)
            #Normal data
            batch_data[folder,idx] = (resized)
            
            #Data with affine transformation
            batch_data_aug[folder,idx] = (cv2.warpAffine(resized, M, (resized.shape[0], resized.shape[1])))
            
            # Data with horizontal flip
            batch_data_flip[folder,idx]= np.flip(resized,1)

        batch_labels[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        batch_labels_aug[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        
        # Labeling data with horizobtal flip, right swipe becomes left swipe and viceversa
        if int(t[folder + (batch_num*batch_size)].strip().split(';')[2])==0:
                    batch_labels_flip[folder, 1] = 1
        elif int(t[folder + (batch_num*batch_size)].strip().split(';')[2])==1:
                    batch_labels_flip[folder, 0] = 1
                    
        else:
                    batch_labels_flip[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
                  
    
    batch_data_final = np.append(batch_data, batch_data_aug, axis = 0)
    batch_data_final = np.append(batch_data_final, batch_data_flip, axis = 0)

    batch_labels_final = np.append(batch_labels, batch_labels_aug, axis = 0) 
    batch_labels_final = np.append(batch_labels_final, batch_labels_flip, axis = 0)
    
    if validation:
        batch_data_final=batch_data
        batch_labels_final= batch_labels
        
    return batch_data_final,batch_labels_final

# %%
def generator(source_path, folder_list, batch_size, validation=False):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            # you yield the batch_data and the batch_labels, remember what does yield do
            yield process_batch_images(source_path, folder_list, batch, batch_size, t,validation)       
        
        # Code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            yield process_batch_images(source_path, folder_list, batch, batch_size, t,validation)

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %% [markdown]
# ## Model 6

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam

#nb_filters = [8,16,32,64]
#nb_dense = [256, 128, 5]

# Input
input_shape=(nb_frames,nb_rows,nb_cols,nb_channel)

# Define model

model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=input_shape, padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(1,3,3), padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(64, kernel_size=(1,3,3), padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(MaxPooling3D(pool_size=(2,2,2)))

#Flatten Layers
model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 30, 120, 120, 8)   656
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 120, 120, 8)   0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 120, 120, 8)   0
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 15, 60, 60, 8)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 15, 60, 60, 16)    3472
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 7, 30, 30, 16)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 30, 30, 32)     4640
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 30, 30, 32)     0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 30, 30, 32)     0
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 3, 15, 15, 32)     0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 3, 15, 15, 64)     18496
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 1, 7, 7, 64)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               803072
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 863,877
# Trainable params: 863,877
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size,validation=True)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

# write the Reducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
batch_size = 10
num_epochs = 20
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ./Project_data/val ; batch size = 10
# Source path =  ./Project_data/train ; batch size = 10Epoch 1/20
#
# 67/67 [==============================] - 193s 3s/step - loss: 13.0589 - categorical_accuracy: 0.1882 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 00001: saving model to model_init_2020-03-3012_49_46.379324/model-00001-13.04575-0.18904-13.53920-0.16000.h5
# Epoch 2/20
# 67/67 [==============================] - 29s 432ms/step - loss: 13.5253 - categorical_accuracy: 0.1609 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 00002: saving model to model_init_2020-03-3012_49_46.379324/model-00002-13.52530-0.16086-13.53920-0.16000.h5
# Epoch 3/20
# 67/67 [==============================] - 32s 477ms/step - loss: 12.9640 - categorical_accuracy: 0.1957 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 00003: saving model to model_init_2020-03-3012_49_46.379324/model-00003-12.96397-0.19569-13.53920-0.16000.h5
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 4/20
# 67/67 [==============================] - 31s 462ms/step - loss: 13.1766 - categorical_accuracy: 0.1824 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 00004: saving model to model_init_2020-03-3012_49_46.379324/model-00004-13.17658-0.18242-13.53920-0.16000.h5
# Epoch 5/20
# 67/67 [==============================] - 32s 472ms/step - loss: 12.8838 - categorical_accuracy: 0.2007 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 00005: saving model to model_init_2020-03-3012_49_46.379324/model-00005-12.88378-0.20066-13.53920-0.16000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 6/20
# 67/67 [==============================] - 32s 477ms/step - loss: 12.9105 - categorical_accuracy: 0.1990 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 00006: saving model to model_init_2020-03-3012_49_46.379324/model-00006-12.91051-0.19900-13.53920-0.16000.h5
# Epoch 7/20
# 67/67 [==============================] - 30s 450ms/step - loss: 13.1986 - categorical_accuracy: 0.1808 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 00007: saving model to model_init_2020-03-3012_49_46.379324/model-00007-13.19864-0.18076-13.53920-0.16000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 8/20
# 67/67 [==============================] - 28s 414ms/step - loss: 13.1867 - categorical_accuracy: 0.1808 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 00008: saving model to model_init_2020-03-3012_49_46.379324/model-00008-13.18674-0.18076-13.53920-0.16000.h5
# Epoch 9/20
# 67/67 [==============================] - 29s 427ms/step - loss: 13.3115 - categorical_accuracy: 0.1741 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 00009: saving model to model_init_2020-03-3012_49_46.379324/model-00009-13.31146-0.17413-13.53920-0.16000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 10/20
# 67/67 [==============================] - 26s 394ms/step - loss: 12.2271 - categorical_accuracy: 0.2405 - val_loss: 13.5392 - val_categorical_accuracy: 0.1600
#
# Epoch 
- val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00028: saving model to model_init_2020-03-3012_49_46.379324/model-00028-13.17590-0.18254-14.50629-0.10000.h5
# Epoch 29/30
# 14/14 [==============================] - 5s 375ms/step - loss: 13.4317 - categorical_accuracy: 0.1667 - val_loss: 12.8945 - val_categorical_accuracy: 0.2000
#
# Epoch 00029: saving model to model_init_2020-03-3012_49_46.379324/model-00029-13.43175-0.16667-12.89448-0.20000.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 5.684342156072553e-17.
# Epoch 30/30
# 14/14 [==============================] - 6s 411ms/step - loss: 12.5363 - categorical_accuracy: 0.2222 - val_loss: 12.8945 - val_categorical_accuracy: 0.2000
#
# Epoch 00030: saving model to model_init_2020-03-3012_49_46.379324/model-00030-12.53630-0.22222-12.89448-0.20000.h5

# %%
batch_size = 90
num_epochs = 30

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 4s 507ms/step - loss: 14.5511 - categorical_accuracy: 0.0972 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00001: saving model to model_init_2020-03-3012_49_46.379324/model-00001-14.55106-0.09722-13.70038-0.15000.h5
# Epoch 2/30
# 8/8 [==============================] - 4s 454ms/step - loss: 12.7602 - categorical_accuracy: 0.2083 - val_loss: 12.8945 - val_categorical_accuracy: 0.2000
#
# Epoch 00002: saving model to model_init_2020-03-3012_49_46.379324/model-00002-12.76016-0.20833-12.89448-0.20000.h5
# Epoch 3/30
# 8/8 [==============================] - 4s 445ms/step - loss: 10.7454 - categorical_accuracy: 0.3333 - val_loss: 12.8945 - val_categorical_accuracy: 0.2000
#
# Epoch 00003: saving model to model_init_2020-03-3012_49_46.379324/model-00003-10.74540-0.33333-12.89448-0.20000.h5
# Epoch 4/30
# 8/8 [==============================] - 3s 415ms/step - loss: 14.1033 - categorical_accuracy: 0.1250 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00004: saving model to model_init_2020-03-3012_49_46.379324/model-00004-14.10333-0.12500-13.70038-0.15000.h5
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 2.842171078036277e-17.
# Epoch 5/30
# 8/8 [==============================] - 3s 410ms/step - loss: 10.9693 - categorical_accuracy: 0.3194 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00005: saving model to model_init_2020-03-3012_49_46.379324/model-00005-10.96926-0.31944-13.70038-0.15000.h5
# Epoch 6/30
# 8/8 [==============================] - 3s 433ms/step - loss: 11.4170 - categorical_accuracy: 0.2917 - val_loss: 12.8945 - val_categorical_accuracy: 0.2000
#
# Epoch 00006: saving model to model_init_2020-03-3012_49_46.379324/model-00006-11.41698-0.29167-12.89448-0.20000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 1.4210855390181384e-17.
# Epoch 7/30
# 8/8 [==============================] - 3s 393ms/step - loss: 15.2243 - categorical_accuracy: 0.0556 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00007: saving model to model_init_2020-03-3012_49_46.379324/model-00007-15.22428-0.05556-13.70038-0.15000.h5
# Epoch 8/30
# 8/8 [==============================] - 3s 425ms/step - loss: 14.3273 - categorical_accuracy: 0.1111 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00008: saving model to model_init_2020-03-3012_49_46.379324/model-00008-14.32729-0.11111-13.70038-0.15000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 7.105427695090692e-18.
# Epoch 9/30
# 8/8 [==============================] - 4s 520ms/step - loss: 14.1033 - categorical_accuracy: 0.1250 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00009: saving model to model_init_2020-03-3012_49_46.379324/model-00009-14.10333-0.12500-13.70038-0.15000.h5
# Epoch 10/30
# 8/8 [==============================] - 4s 464ms/step - loss: 12.9840 - categorical_accuracy: 0.1944 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00010: saving model to model_init_2020-03-3012_49_46.379324/model-00010-12.98402-0.19444-12.08857-0.25000.h5
# Epoch 11/30
# 8/8 [==============================] - 4s 439ms/step - loss: 12.0886 - categorical_accuracy: 0.2500 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00011: saving model to model_init_2020-03-3012_49_46.379324/model-00011-12.08857-0.25000-13.70038-0.15000.h5
# Epoch 12/30
# 8/8 [==============================] - 3s 422ms/step - loss: 14.3272 - categorical_accuracy: 0.1111 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00012: saving model to model_init_2020-03-3012_49_46.379324/model-00012-14.32720-0.11111-13.70038-0.15000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 3.552713847545346e-18.
# Epoch 13/30
# 8/8 [==============================] - 3s 430ms/step - loss: 13.7596 - categorical_accuracy: 0.1389 - val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00013: saving model to model_init_2020-03-3012_49_46.379324/model-00013-13.75956-0.13889-14.50629-0.10000.h5
# Epoch 14/30
# 8/8 [==============================] - 3s 369ms/step - loss: 12.5363 - categorical_accuracy: 0.2222 - val_loss: 11.2827 - val_categorical_accuracy: 0.3000
#
# Epoch 00014: saving model to model_init_2020-03-3012_49_46.379324/model-00014-12.53630-0.22222-11.28267-0.30000.h5
# Epoch 15/30
# 8/8 [==============================] - 4s 485ms/step - loss: 14.1033 - categorical_accuracy: 0.1250 - val_loss: 15.3122 - val_categorical_accuracy: 0.0500
#
# Epoch 00015: saving model to model_init_2020-03-3012_49_46.379324/model-00015-14.10333-0.12500-15.31219-0.05000.h5
# Epoch 16/30
# 8/8 [==============================] - 3s 411ms/step - loss: 12.9840 - categorical_accuracy: 0.1944 - val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00016: saving model to model_init_2020-03-3012_49_46.379324/model-00016-12.98402-0.19444-14.50629-0.10000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.776356923772673e-18.
# Epoch 17/30
# 8/8 [==============================] - 3s 407ms/step - loss: 11.6408 - categorical_accuracy: 0.2778 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00017: saving model to model_init_2020-03-3012_49_46.379324/model-00017-11.64085-0.27778-12.08857-0.25000.h5
# Epoch 18/30
# 8/8 [==============================] - 4s 472ms/step - loss: 12.9840 - categorical_accuracy: 0.1944 - val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00018: saving model to model_init_2020-03-3012_49_46.379324/model-00018-12.98402-0.19444-14.50629-0.10000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 8.881784618863365e-19.
# Epoch 19/30
# 8/8 [==============================] - 3s 433ms/step - loss: 12.9840 - categorical_accuracy: 0.1944 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00019: saving model to model_init_2020-03-3012_49_46.379324/model-00019-12.98402-0.19444-13.70038-0.15000.h5
# Epoch 20/30
# 8/8 [==============================] - 4s 447ms/step - loss: 12.5363 - categorical_accuracy: 0.2222 - val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00020: saving model to model_init_2020-03-3012_49_46.379324/model-00020-12.53630-0.22222-14.50629-0.10000.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.440892309431682e-19.
# Epoch 21/30
# 8/8 [==============================] - 4s 438ms/step - loss: 12.0886 - categorical_accuracy: 0.2500 - val_loss: 12.8945 - val_categorical_accuracy: 0.2000
#
# Epoch 00021: saving model to model_init_2020-03-3012_49_46.379324/model-00021-12.08857-0.25000-12.89448-0.20000.h5
# Epoch 22/30
# 8/8 [==============================] - 4s 508ms/step - loss: 12.7602 - categorical_accuracy: 0.2083 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00022: saving model to model_init_2020-03-3012_49_46.379324/model-00022-12.76016-0.20833-13.70038-0.15000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 2.220446154715841e-19.
# Epoch 23/30
# 8/8 [==============================] - 3s 415ms/step - loss: 13.4317 - categorical_accuracy: 0.1667 - val_loss: 12.8945 - val_categorical_accuracy: 0.2000
#
# Epoch 00023: saving model to model_init_2020-03-3012_49_46.379324/model-00023-13.43175-0.16667-12.89448-0.20000.h5
# Epoch 24/30
# 8/8 [==============================] - 4s 498ms/step - loss: 14.1033 - categorical_accuracy: 0.1250 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00024: saving model to model_init_2020-03-3012_49_46.379324/model-00024-14.10333-0.12500-12.08857-0.25000.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.1102230773579206e-19.
# Epoch 25/30
# 8/8 [==============================] - 4s 488ms/step - loss: 12.5363 - categorical_accuracy: 0.2222 - val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00025: saving model to model_init_2020-03-3012_49_46.379324/model-00025-12.53630-0.22222-14.50629-0.10000.h5
# Epoch 26/30
# 8/8 [==============================] - 3s 405ms/step - loss: 12.3124 - categorical_accuracy: 0.2361 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00026: saving model to model_init_2020-03-3012_49_46.379324/model-00026-12.31243-0.23611-13.70038-0.15000.h5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 5.551115386789603e-20.
# Epoch 27/30
# 8/8 [==============================] - 3s 413ms/step - loss: 12.3124 - categorical_accuracy: 0.2361 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00027: saving model to model_init_2020-03-3012_49_46.379324/model-00027-12.31243-0.23611-13.70038-0.15000.h5
# Epoch 28/30
# 8/8 [==============================] - 3s 393ms/step - loss: 15.2226 - categorical_accuracy: 0.0556 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00028: saving model to model_init_2020-03-3012_49_46.379324/model-00028-15.22265-0.05556-13.70038-0.15000.h5
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 2.7755576933948015e-20.
# Epoch 29/30
# 8/8 [==============================] - 4s 461ms/step - loss: 12.5363 - categorical_accuracy: 0.2222 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00029: saving model to model_init_2020-03-3012_49_46.379324/model-00029-12.53630-0.22222-12.08857-0.25000.h5
# Epoch 30/30
# 8/8 [==============================] - 4s 450ms/step - loss: 13.4317 - categorical_accuracy: 0.1667 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00030: saving model to model_init_2020-03-3012_49_46.379324/model-00030-13.43175-0.16667-13.70038-0.15000.h5
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.3877788466974007e-20.

# %%
batch_size = 90
num_epochs = 20

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    

model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 4s 451ms/step - loss: 12.9840 - categorical_accuracy: 0.1944 - val_loss: 12.8945 - val_categorical_accuracy: 0.2000
#
# Epoch 00001: saving model to model_init_2020-03-3012_49_46.379324/model-00001-12.98402-0.19444-12.89448-0.20000.h5
# Epoch 2/20
# 8/8 [==============================] - 4s 496ms/step - loss: 14.3272 - categorical_accuracy: 0.1111 - val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00002: saving model to model_init_2020-03-3012_49_46.379324/model-00002-14.32720-0.11111-14.50629-0.10000.h5
# Epoch 3/20
# 8/8 [==============================] - 4s 449ms/step - loss: 11.8647 - categorical_accuracy: 0.2639 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00003: saving model to model_init_2020-03-3012_49_46.379324/model-00003-11.86471-0.26389-12.08857-0.25000.h5
# Epoch 4/20
# 8/8 [==============================] - 3s 390ms/step - loss: 14.9988 - categorical_accuracy: 0.0694 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00004: saving model to model_init_2020-03-3012_49_46.379324/model-00004-14.99878-0.06944-13.70038-0.15000.h5
# Epoch 5/20
# 8/8 [==============================] - 3s 404ms/step - loss: 12.5363 - categorical_accuracy: 0.2222 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00005: saving model to model_init_2020-03-3012_49_46.379324/model-00005-12.53630-0.22222-13.70038-0.15000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 6.938894233487004e-21.
# Epoch 6/20
# 8/8 [==============================] - 4s 447ms/step - loss: 13.8795 - categorical_accuracy: 0.1389 - val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00006: saving model to model_init_2020-03-3012_49_46.379324/model-00006-13.87947-0.13889-14.50629-0.10000.h5
# Epoch 7/20
# 8/8 [==============================] - 4s 446ms/step - loss: 14.7749 - categorical_accuracy: 0.0833 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00007: saving model to model_init_2020-03-3012_49_46.379324/model-00007-14.77492-0.08333-13.70038-0.15000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 3.469447116743502e-21.
# Epoch 8/20
# 8/8 [==============================] - 3s 424ms/step - loss: 13.4317 - categorical_accuracy: 0.1667 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00008: saving model to model_init_2020-03-3012_49_46.379324/model-00008-13.43175-0.16667-12.08857-0.25000.h5
# Epoch 9/20
# 8/8 [==============================] - 3s 431ms/step - loss: 13.2079 - categorical_accuracy: 0.1806 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00009: saving model to model_init_2020-03-3012_49_46.379324/model-00009-13.20788-0.18056-13.70038-0.15000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.734723558371751e-21.
# Epoch 10/20
# 8/8 [==============================] - 3s 399ms/step - loss: 12.3124 - categorical_accuracy: 0.2361 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00010: saving model to model_init_2020-03-3012_49_46.379324/model-00010-12.31243-0.23611-13.70038-0.15000.h5
# Epoch 11/20
# 8/8 [==============================] - 3s 392ms/step - loss: 14.7749 - categorical_accuracy: 0.0833 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00011: saving model to model_init_2020-03-3012_49_46.379324/model-00011-14.77492-0.08333-12.08857-0.25000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 8.673617791858755e-22.
# Epoch 12/20
# 8/8 [==============================] - 3s 357ms/step - loss: 11.4170 - categorical_accuracy: 0.2917 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00012: saving model to model_init_2020-03-3012_49_46.379324/model-00012-11.41698-0.29167-12.08857-0.25000.h5
# Epoch 13/20
# 8/8 [==============================] - 3s 393ms/step - loss: 11.8647 - categorical_accuracy: 0.2639 - val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00013: saving model to model_init_2020-03-3012_49_46.379324/model-00013-11.86471-0.26389-14.50629-0.10000.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 4.336808895929377e-22.
# Epoch 14/20
# 8/8 [==============================] - 3s 378ms/step - loss: 11.6408 - categorical_accuracy: 0.2778 - val_loss: 15.3122 - val_categorical_accuracy: 0.0500
#
# Epoch 00014: saving model to model_init_2020-03-3012_49_46.379324/model-00014-11.64085-0.27778-15.31219-0.05000.h5
# Epoch 15/20
# 8/8 [==============================] - 4s 445ms/step - loss: 11.4170 - categorical_accuracy: 0.2917 - val_loss: 14.5063 - val_categorical_accuracy: 0.1000
#
# Epoch 00015: saving model to model_init_2020-03-3012_49_46.379324/model-00015-11.41698-0.29167-14.50629-0.10000.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.1684044479646887e-22.
# Epoch 16/20
# 8/8 [==============================] - 3s 392ms/step - loss: 12.0886 - categorical_accuracy: 0.2500 - val_loss: 15.3122 - val_categorical_accuracy: 0.0500
#
# Epoch 00016: saving model to model_init_2020-03-3012_49_46.379324/model-00016-12.08857-0.25000-15.31219-0.05000.h5
# Epoch 17/20
# 8/8 [==============================] - 3s 432ms/step - loss: 13.8795 - categorical_accuracy: 0.1389 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00017: saving model to model_init_2020-03-3012_49_46.379324/model-00017-13.87947-0.13889-12.08857-0.25000.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0842022239823443e-22.
# Epoch 18/20
# 8/8 [==============================] - 3s 422ms/step - loss: 13.2079 - categorical_accuracy: 0.1806 - val_loss: 13.7004 - val_categorical_accuracy: 0.1500
#
# Epoch 00018: saving model to model_init_2020-03-3012_49_46.379324/model-00018-13.20788-0.18056-13.70038-0.15000.h5
# Epoch 19/20
# 8/8 [==============================] - 3s 356ms/step - loss: 14.1033 - categorical_accuracy: 0.1250 - val_loss: 12.0886 - val_categorical_accuracy: 0.2500
#
# Epoch 00019: saving model to model_init_2020-03-3012_49_46.379324/model-00019-14.10333-0.12500-12.08857-0.25000.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 5.421011119911722e-23.
# Epoch 20/20
# 8/8 [==============================] - 3s 423ms/step - loss: 12.5363 - categorical_accuracy: 0.2222 - val_loss: 15.3122 - val_categorical_accuracy: 0.0500
#
# Epoch 00020: saving model to model_init_2020-03-3012_49_46.379324/model-00020-12.53630-0.22222-15.31219-0.05000.h5
