# %% [markdown]
# # Gesture Recognition - Model 10
# #### CNN+GRU
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly.

# %%
import numpy as np
import os
import datetime
import os
import cv2

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.set_random_seed(30)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# In this block, you read the folder names for training and validation. We will set the initial `batch_size` here. Note that we will experimentally set the batch size in such a way that you are able to use the GPU in full capacity. Keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('./Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('./Project_data/val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %% [markdown]
# ## Generator and Preprocessing Functions
# This is one of the most important part of the code. The overall structure of the generator is broken down into modules. In the generator, we are going to preprocess the images as we have images of 2 different dimensions as well as create a batch of video frames.

# %%
# Parameters initialization
nb_rows = 120   # X dimension of the image
nb_cols = 120   # Y dimesnion of the image
nb_frames = 30  # lenght of the video frames
nb_channel = 3  # number of channels in images 3 for color(RGB) and 1 for Gray

# %%
# Helper function to generate a random affine transform on the iamge
def get_random_affine():
    dx, dy = np.random.randint(-1.7, 1.8, 2)
    M = np.float32([[1, 0, dx], [0, 1, dy]])
    return M

# %%
# Helper function to initialize all the batch image data and labels
def init_batch_data(batch_size):
    batch_data = np.zeros((batch_size, nb_frames, nb_rows, nb_cols, nb_channel)) 
    batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
    return batch_data, batch_labels

# %%
def process_batch_images(source_path, folder_list, batch_num, batch_size, t,validation):
    
    batch_data,batch_labels = init_batch_data(batch_size)
    
    # For building an augumented batch data with affine transformation
    batch_data_aug,batch_labels_aug = init_batch_data(batch_size)
    
    # For building an augmented batch data with horizontal flip
    batch_data_flip,batch_labels_flip = init_batch_data(batch_size)
    
    #create a list of image numbers you want to use for a particular video using full frames
    img_idx = [x for x in range(0, nb_frames)] 

    for folder in range(batch_size): # iterate over the batch_size
        # read all the images in the folder
        imgs = sorted(os.listdir(source_path+'/'+ t[folder + (batch_num*batch_size)].split(';')[0])) 
        # Generating a random affine to be used in image transformation for buidling agumented data set
        M = get_random_affine()
        
        #  Iterate over the frames/images of a folder to read them in
        for idx, item in enumerate(img_idx): 
            image = cv2.imread(source_path+'/'+ t[folder + (batch_num*batch_size)].strip().split(';')[0]+'/'+imgs[item], cv2.IMREAD_COLOR)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            # Cropping non symmetric frames
            if image.shape[0] != image.shape[1]:
                image=image[0:120,20:140]
            
            #crop the images and resize them. Note that the images are of 2 different shape 
            #and the conv3D will throw error if the inputs in a batch have different shapes   
            resized = cv2.resize(image, (nb_rows,nb_cols), interpolation = cv2.INTER_AREA)
            #Normal data
            batch_data[folder,idx] = (resized)
            
            #Data with affine transformation
            batch_data_aug[folder,idx] = (cv2.warpAffine(resized, M, (resized.shape[0], resized.shape[1])))
            
            # Data with horizontal flip
            batch_data_flip[folder,idx]= np.flip(resized,1)

        batch_labels[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        batch_labels_aug[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        
        # Labeling data with horizobtal flip, right swipe becomes left swipe and viceversa
        if int(t[folder + (batch_num*batch_size)].strip().split(';')[2])==0:
                    batch_labels_flip[folder, 1] = 1
        elif int(t[folder + (batch_num*batch_size)].strip().split(';')[2])==1:
                    batch_labels_flip[folder, 0] = 1
                    
        else:
                    batch_labels_flip[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
                  
    
    batch_data_final = np.append(batch_data, batch_data_aug, axis = 0)
    batch_data_final = np.append(batch_data_final, batch_data_flip, axis = 0)

    batch_labels_final = np.append(batch_labels, batch_labels_aug, axis = 0) 
    batch_labels_final = np.append(batch_labels_final, batch_labels_flip, axis = 0)
    
    if validation:
        batch_data_final=batch_data
        batch_labels_final= batch_labels
        
    return batch_data_final,batch_labels_final

# %%
def generator(source_path, folder_list, batch_size, validation=False):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            # you yield the batch_data and the batch_labels, remember what does yield do
            yield process_batch_images(source_path, folder_list, batch, batch_size, t,validation)            
        
        # Code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            yield process_batch_images(source_path, folder_list, batch, batch_size, t,validation)

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %% [markdown]
# ## Final Model

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, Conv2D, MaxPooling3D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from keras.layers.recurrent import LSTM

#nb_filters = [8,16,32,64]
#nb_dense = [256, 128, 5]

nb_classes = 5

# Input
input_shape=(nb_frames,nb_rows,nb_cols,nb_channel)

# Define model
model = Sequential()

model.add(TimeDistributed(Conv2D(32, (7, 7), strides=(2, 2),
            activation='relu', padding='same'), input_shape=input_shape))
model.add(TimeDistributed(Conv2D(32, (3,3),
            kernel_initializer="he_normal", activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model.add(TimeDistributed(Conv2D(64, (3,3),
            padding='same', activation='relu')))
model.add(TimeDistributed(Conv2D(64, (3,3),
            padding='same', activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model.add(TimeDistributed(Conv2D(128, (3,3),
            padding='same', activation='relu')))
model.add(TimeDistributed(Conv2D(128, (3,3),
            padding='same', activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model.add(TimeDistributed(Conv2D(256, (3,3),
            padding='same', activation='relu')))
model.add(TimeDistributed(Conv2D(256, (3,3),
            padding='same', activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))
        
model.add(TimeDistributed(Conv2D(512, (3,3),
            padding='same', activation='relu')))
model.add(TimeDistributed(Conv2D(512, (3,3),
            padding='same', activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model.add(TimeDistributed(Flatten()))

model.add(Dropout(0.5))
model.add(GRU(256, return_sequences=False, dropout=0.5))
model.add(Dense(nb_classes, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_1 (TimeDist (None, 30, 60, 60, 32)    4736
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 30, 58, 58, 32)    9248
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 30, 29, 29, 32)    0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 30, 29, 29, 64)    18496
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 30, 29, 29, 64)    36928
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 30, 14, 14, 64)    0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 30, 14, 14, 128)   73856
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 30, 14, 14, 128)   147584
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 30, 7, 7, 128)     0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 30, 7, 7, 256)     295168
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 30, 7, 7, 256)     590080
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 30, 3, 3, 256)     0
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 30, 3, 3, 512)     1180160
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 30, 3, 3, 512)     2359808
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 30, 1, 1, 512)     0
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 30, 512)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 512)           0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 256)               590592
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 5,307,941
# Trainable params: 5,307,941
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size,validation=True)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

# write the Reducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
batch_size = 10
num_epochs = 20
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  Source path =  ./Project_data/train./Project_data/val ; batch size = 10
# Epoch 1/20
#  ; batch size = 10
# 67/67 [==============================] - 173s 3s/step - loss: 2.1415 - categorical_accuracy: 0.1892 - val_loss: 1.7690 - val_categorical_accuracy: 0.2000
#
# Epoch 00001: saving model to model_init_2020-03-3004_11_09.920829/model-00001-2.14401-0.19005-1.76897-0.20000.h5
# Epoch 2/20
# 67/67 [==============================] - 31s 461ms/step - loss: 2.0520 - categorical_accuracy: 0.2007 - val_loss: 1.7016 - val_categorical_accuracy: 0.2000
#
# Epoch 00002: saving model to model_init_2020-03-3004_11_09.920829/model-00002-2.05202-0.20066-1.70160-0.20000.h5
# Epoch 3/20
# 67/67 [==============================] - 33s 493ms/step - loss: 1.9974 - categorical_accuracy: 0.1957 - val_loss: 1.6835 - val_categorical_accuracy: 0.1300
#
# Epoch 00003: saving model to model_init_2020-03-3004_11_09.920829/model-00003-1.99736-0.19569-1.68349-0.13000.h5
# Epoch 4/20
# 67/67 [==============================] - 32s 482ms/step - loss: 1.9024 - categorical_accuracy: 0.1940 - val_loss: 1.6920 - val_categorical_accuracy: 0.1300
#
# Epoch 00004: saving model to model_init_2020-03-3004_11_09.920829/model-00004-1.90242-0.19403-1.69204-0.13000.h5
# Epoch 5/20
# 67/67 [==============================] - 33s 490ms/step - loss: 1.8457 - categorical_accuracy: 0.2272 - val_loss: 1.7479 - val_categorical_accuracy: 0.1700
#
# Epoch 00005: saving model to model_init_2020-03-3004_11_09.920829/model-00005-1.84575-0.22720-1.74793-0.17000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/20
# 67/67 [==============================] - 34s 507ms/step - loss: 1.8832 - categorical_accuracy: 0.2156 - val_loss: 1.7247 - val_categorical_accuracy: 0.2100
#
# Epoch 00006: saving model to model_init_2020-03-3004_11_09.920829/model-00006-1.88325-0.21559-1.72474-0.21000.h5
# Epoch 7/20
# 67/67 [==============================] - 32s 482ms/step - loss: 1.8576 - categorical_accuracy: 0.1791 - val_loss: 1.6766 - val_categorical_accuracy: 0.1700
#
# Epoch 00007: saving model to model_init_2020-03-3004_11_09.920829/model-00007-1.85764-0.17910-1.67663-0.17000.h5
# Epoch 8/20
# 67/67 [==============================] - 33s 487ms/step - loss: 1.8566 - categorical_accuracy: 0.1924 - val_loss: 1.6711 - val_categorical_accuracy: 0.2100
#
# Epoch 00008: saving model to model_init_2020-03-3004_11_09.920829/model-00008-1.85661-0.19237-1.67109-0.21000.h5
# Epoch 9/20
# 67/67 [==============================] - 32s 481ms/step - loss: 1.8508 - categorical_accuracy: 0.1725 - val_loss: 1.7337 - val_categorical_accuracy: 0.2100
#
# Epoch 00009: saving model to model_init_2020-03-3004_11_09.920829/model-00009-1.85083-0.17247-1.73368-0.21000.h5
# Epoch 10/20
# 67/67 [==============================] - 29s 440ms/step - loss: 1.7962 - categorical_accuracy: 0.2156 - val_loss: 1.7021 - val_categorical_accuracy: 0.1900
#
# Epoch 00010: saving model to model_init_2020-03-3004_11_09.920829/model-00010-1.79624-0.21559-1.70210-0.19000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/20
# 67/67 [==============================] - 29s 430ms/step - loss: 1.7599 - categorical_accuracy: 0.2322 - val_loss: 1.6809 - val_categorical_accuracy: 0.2100
#
# Epoch 00011: saving model to model_init_2020-03-3004_11_09.920829/model-00011-1.75990-0.23217-1.68092-0.21000.h5
# Epoch 12/20
# 67/67 [==============================] - 30s 444ms/step - loss: 1.8194 - categorical_accuracy: 0.1725 - val_loss: 1.7322 - val_categorical_accuracy: 0.2100
#
# Epoch 00012: saving model to model_init_2020-03-3004_11_09.920829/model-00012-1.81945-0.17247-1.73219-0.21000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/20
# 67/67 [==============================] - 31s 456ms/step - loss: 1.7462 - categorical_accuracy: 0.2139 - val_loss: 1.7389 - val_categorical_accuracy: 0.2100
#
# Epoch 00013: saving model to model_init_2020-03-3004_11_09.920829/model-00013-1.74617-0.21393-1.73891-0.21000.h5
# Epoch 14/20
# 67/67 [==============================] - 29s 437ms/step - loss: 1.7923 - categorical_accuracy: 0.1907 - val_loss: 1.7227 - val_categorical_accuracy: 0.2100
#
# Epoch 00014: saving model to model_init_2020-03-3004_11_09.920829/model-00014-1.79227-0.19071-1.72269-0.21000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 15/20
# 67/67 [==============================] - 30s 441ms/step - loss: 1.7796 - categorical_accuracy: 0.2156 - val_loss: 1.7135 - val_categorical_accuracy: 0.2100
#
# Epoch 00015: saving model to model_init_2020-03-3004_11_09.920829/model-00015-1.77964-0.21559-1.71352-0.21000.h5
# Epoch 16/20
# 67/67 [==============================] - 28s 422ms/step - loss: 1.7863 - categorical_accuracy: 0.2090 - val_loss: 1.7219 - val_categorical_accuracy: 0.2100
#
# Epoch 00016: saving model to model_init_2020-03-3004_11_09.920829/model-00016-1.78635-0.20896-1.72194-0.21000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 17/20
# 67/67 [==============================] - 29s 436ms/step - loss: 1.7988 - categorical_accuracy: 0.1841 - val_loss: 1.7254 - val_categorical_accuracy: 0.2100
#
# Epoch 00017: saving model to model_init_2020-03-3004_11_09.920829/model-00017-1.79885-0.18408-1.72539-0.21000.h5
# Epoch 18/20
# 67/67 [==============================] - 30s 444ms/step - loss: 1.7778 - categorical_accuracy: 0.2139 - val_loss: 1.7255 - val_categorical_accuracy: 0.2100
#
# Epoch 00018: saving model to model_init_2020-03-3004_11_09.920829/model-00018-1.77783-0.21393-1.72551-0.21000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 19/20
# 67/67 [==============================] - 29s 432ms/step - loss: 1.7739 - categorical_accuracy: 0.1973 - val_loss: 1.7257 - val_categorical_accuracy: 0.2100
#
# Epoch 00019: saving model to model_init_2020-03-3004_11_09.920829/model-00019-1.77390-0.19735-1.72566-0.21000.h5
# Epoch 20/20
# 67/67 [==============================] - 30s 443ms/step - loss: 1.7706 - categorical_accuracy: 0.1841 - val_loss: 1.7333 - val_categorical_accuracy: 0.2100
#
# Epoch 00020: saving model to model_init_2020-03-3004_11_09.920829/model-00020-1.77058-0.18408-1.73330-0.21000.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.

# %%
batch_size = 20
num_epochs = 20

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 34/34 [==============================] - 17s 488ms/step - loss: 1.8361 - categorical_accuracy: 0.2026 - val_loss: 1.6939 - val_categorical_accuracy: 0.2200
#
# Epoch 00001: saving model to model_init_2020-03-3004_11_09.920829/model-00001-1.83614-0.20261-1.69387-0.22000.h5
# Epoch 2/20
# 34/34 [==============================] - 15s 440ms/step - loss: 1.7850 - categorical_accuracy: 0.1536 - val_loss: 1.6765 - val_categorical_accuracy: 0.2800
#
# Epoch 00002: saving model to model_init_2020-03-3004_11_09.920829/model-00002-1.78502-0.15359-1.67651-0.28000.h5
# Epoch 3/20
# 34/34 [==============================] - 15s 433ms/step - loss: 1.7961 - categorical_accuracy: 0.1863 - val_loss: 1.7009 - val_categorical_accuracy: 0.2600
#
# Epoch 00003: saving model to model_init_2020-03-3004_11_09.920829/model-00003-1.79610-0.18627-1.70095-0.26000.h5
# Epoch 4/20
# 34/34 [==============================] - 14s 416ms/step - loss: 1.8310 - categorical_accuracy: 0.1601 - val_loss: 1.8238 - val_categorical_accuracy: 0.1200
#
# Epoch 00004: saving model to model_init_2020-03-3004_11_09.920829/model-00004-1.83100-0.16013-1.82379-0.12000.h5
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 5/20
# 34/34 [==============================] - 14s 420ms/step - loss: 1.7860 - categorical_accuracy: 0.2124 - val_loss: 1.6709 - val_categorical_accuracy: 0.2400
#
# Epoch 00005: saving model to model_init_2020-03-3004_11_09.920829/model-00005-1.78597-0.21242-1.67093-0.24000.h5
# Epoch 6/20
# 34/34 [==============================] - 14s 416ms/step - loss: 1.8028 - categorical_accuracy: 0.1961 - val_loss: 1.7997 - val_categorical_accuracy: 0.1400
#
# Epoch 00006: saving model to model_init_2020-03-3004_11_09.920829/model-00006-1.80278-0.19608-1.79966-0.14000.h5
# Epoch 7/20
# 34/34 [==============================] - 14s 413ms/step - loss: 1.8074 - categorical_accuracy: 0.1895 - val_loss: 1.7747 - val_categorical_accuracy: 0.2000
#
# Epoch 00007: saving model to model_init_2020-03-3004_11_09.920829/model-00007-1.80740-0.18954-1.77465-0.20000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 8/20
# 34/34 [==============================] - 14s 415ms/step - loss: 1.8611 - categorical_accuracy: 0.1634 - val_loss: 1.6554 - val_categorical_accuracy: 0.2800
#
# Epoch 00008: saving model to model_init_2020-03-3004_11_09.920829/model-00008-1.86113-0.16340-1.65539-0.28000.h5
# Epoch 9/20
# 34/34 [==============================] - 14s 418ms/step - loss: 1.8721 - categorical_accuracy: 0.1634 - val_loss: 1.7879 - val_categorical_accuracy: 0.1800
#
# Epoch 00009: saving model to model_init_2020-03-3004_11_09.920829/model-00009-1.87209-0.16340-1.78790-0.18000.h5
# Epoch 10/20
# 34/34 [==============================] - 14s 411ms/step - loss: 1.8115 - categorical_accuracy: 0.1961 - val_loss: 1.6672 - val_categorical_accuracy: 0.2200
#
# Epoch 00010: saving model to model_init_2020-03-3004_11_09.920829/model-00010-1.81149-0.19608-1.66719-0.22000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 11/20
# 34/34 [==============================] - 14s 415ms/step - loss: 1.8736 - categorical_accuracy: 0.1373 - val_loss: 1.8479 - val_categorical_accuracy: 0.1200
#
# Epoch 00011: saving model to model_init_2020-03-3004_11_09.920829/model-00011-1.87357-0.13725-1.84792-0.12000.h5
# Epoch 12/20
# 34/34 [==============================] - 14s 415ms/step - loss: 1.8655 - categorical_accuracy: 0.1765 - val_loss: 1.6564 - val_categorical_accuracy: 0.3000
#
# Epoch 00012: saving model to model_init_2020-03-3004_11_09.920829/model-00012-1.86547-0.17647-1.65641-0.30000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 13/20
# 34/34 [==============================] - 14s 414ms/step - loss: 1.8142 - categorical_accuracy: 0.1732 - val_loss: 1.7102 - val_categorical_accuracy: 0.2000
#
# Epoch 00013: saving model to model_init_2020-03-3004_11_09.920829/model-00013-1.81419-0.17320-1.71015-0.20000.h5
# Epoch 14/20
# 34/34 [==============================] - 14s 415ms/step - loss: 1.7798 - categorical_accuracy: 0.2222 - val_loss: 1.6706 - val_categorical_accuracy: 0.2800
#
# Epoch 00014: saving model to model_init_2020-03-3004_11_09.920829/model-00014-1.77979-0.22222-1.67061-0.28000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 15/20
# 34/34 [==============================] - 14s 415ms/step - loss: 1.7678 - categorical_accuracy: 0.2320 - val_loss: 1.8123 - val_categorical_accuracy: 0.1400
#
# Epoch 00015: saving model to model_init_2020-03-3004_11_09.920829/model-00015-1.76783-0.23203-1.81228-0.14000.h5
# Epoch 16/20
# 34/34 [==============================] - 14s 413ms/step - loss: 1.8341 - categorical_accuracy: 0.1797 - val_loss: 1.7769 - val_categorical_accuracy: 0.2200
#
# Epoch 00016: saving model to model_init_2020-03-3004_11_09.920829/model-00016-1.83415-0.17974-1.77692-0.22000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 17/20
# 34/34 [==============================] - 14s 414ms/step - loss: 1.7652 - categorical_accuracy: 0.1961 - val_loss: 1.7441 - val_categorical_accuracy: 0.1600
#
# Epoch 00017: saving model to model_init_2020-03-3004_11_09.920829/model-00017-1.76517-0.19608-1.74408-0.16000.h5
# Epoch 18/20
# 34/34 [==============================] - 14s 424ms/step - loss: 1.7632 - categorical_accuracy: 0.1863 - val_loss: 1.7057 - val_categorical_accuracy: 0.2600
#
# Epoch 00018: saving model to model_init_2020-03-3004_11_09.920829/model-00018-1.76324-0.18627-1.70567-0.26000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 19/20
# 34/34 [==============================] - 14s 418ms/step - loss: 1.7726 - categorical_accuracy: 0.1961 - val_loss: 1.6910 - val_categorical_accuracy: 0.2200
#
# Epoch 00019: saving model to model_init_2020-03-3004_11_09.920829/model-00019-1.77257-0.19608-1.69100-0.22000.h5
# Epoch 20/20
# 34/34 [==============================] - 14s 415ms/step - loss: 1.7791 - categorical_accuracy: 0.1961 - val_loss: 1.6376 - val_categorical_accuracy: 0.2400
#
# Epoch 00020: saving model to model_init_2020-03-3004_11_09.920829/model-00020-1.77915-0.19608-1.63763-0.24000.h5

# %%
batch_size = 30
num_epochs = 30

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# 23/23 [==============================] - 11s 494ms/step - loss: 1.7885 - categorical_accuracy: 0.1932 - val_loss: 1.7789 - val_categorical_accuracy: 0.2000
#
# Epoch 00001: saving model to model_init_2020-03-3004_11_09.920829/model-00001-1.78846-0.19324-1.77888-0.20000.h5
# Epoch 2/30
# 23/23 [==============================] - 10s 439ms/step - loss: 1.7461 - categorical_accuracy: 0.1981 - val_loss: 1.7068 - val_categorical_accuracy: 0.2250
#
# Epoch 00002: saving model to model_init_2020-03-3004_11_09.920829/model-00002-1.74606-0.19807-1.70679-0.22500.h5
# Epoch 3/30
# 23/23 [==============================] - 10s 434ms/step - loss: 1.7970 - categorical_accuracy: 0.1932 - val_loss: 1.6808 - val_categorical_accuracy: 0.2500
#
# Epoch 00003: saving model to model_init_2020-03-3004_11_09.920829/model-00003-1.79701-0.19324-1.68083-0.25000.h5
# Epoch 4/30
# 23/23 [==============================] - 10s 423ms/step - loss: 1.7993 - categorical_accuracy: 0.1739 - val_loss: 1.6489 - val_categorical_accuracy: 0.2500
#
# Epoch 00004: saving model to model_init_2020-03-3004_11_09.920829/model-00004-1.79934-0.17391-1.64892-0.25000.h5
# Epoch 5/30
# 23/23 [==============================] - 10s 415ms/step - loss: 1.8319 - categorical_accuracy: 0.1739 - val_loss: 1.7273 - val_categorical_accuracy: 0.2250
#
# Epoch 00005: saving model to model_init_2020-03-3004_11_09.920829/model-00005-1.83194-0.17391-1.72727-0.22500.h5
# Epoch 6/30
# 23/23 [==============================] - 10s 417ms/step - loss: 1.7396 - categorical_accuracy: 0.2126 - val_loss: 1.8284 - val_categorical_accuracy: 0.1750
#
# Epoch 00006: saving model to model_init_2020-03-3004_11_09.920829/model-00006-1.73963-0.21256-1.82844-0.17500.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 7/30
# 23/23 [==============================] - 10s 420ms/step - loss: 1.7656 - categorical_accuracy: 0.1739 - val_loss: 1.7281 - val_categorical_accuracy: 0.2000
#
# Epoch 00007: saving model to model_init_2020-03-3004_11_09.920829/model-00007-1.76565-0.17391-1.72813-0.20000.h5
# Epoch 8/30
# 23/23 [==============================] - 10s 420ms/step - loss: 1.7488 - categorical_accuracy: 0.2077 - val_loss: 1.7246 - val_categorical_accuracy: 0.2000
#
# Epoch 00008: saving model to model_init_2020-03-3004_11_09.920829/model-00008-1.74885-0.20773-1.72458-0.20000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 9/30
# 23/23 [==============================] - 10s 420ms/step - loss: 1.7341 - categorical_accuracy: 0.2174 - val_loss: 1.7124 - val_categorical_accuracy: 0.2250
#
# Epoch 00009: saving model to model_init_2020-03-3004_11_09.920829/model-00009-1.73409-0.21739-1.71245-0.22500.h5
# Epoch 10/30
# 23/23 [==============================] - 10s 431ms/step - loss: 1.7869 - categorical_accuracy: 0.1932 - val_loss: 1.6980 - val_categorical_accuracy: 0.2000
#
# Epoch 00010: saving model to model_init_2020-03-3004_11_09.920829/model-00010-1.78690-0.19324-1.69797-0.20000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 11/30
# 23/23 [==============================] - 10s 423ms/step - loss: 1.8708 - categorical_accuracy: 0.1643 - val_loss: 1.7015 - val_categorical_accuracy: 0.2750
#
# Epoch 00011: saving model to model_init_2020-03-3004_11_09.920829/model-00011-1.87076-0.16425-1.70148-0.27500.h5
# Epoch 12/30
# 23/23 [==============================] - 10s 439ms/step - loss: 1.7450 - categorical_accuracy: 0.2077 - val_loss: 1.7676 - val_categorical_accuracy: 0.1750
#
# Epoch 00012: saving model to model_init_2020-03-3004_11_09.920829/model-00012-1.74497-0.20773-1.76755-0.17500.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 13/30
# 23/23 [==============================] - 10s 439ms/step - loss: 1.8060 - categorical_accuracy: 0.1836 - val_loss: 1.7788 - val_categorical_accuracy: 0.1750
#
# Epoch 00013: saving model to model_init_2020-03-3004_11_09.920829/model-00013-1.80599-0.18357-1.77876-0.17500.h5
# Epoch 14/30
# 23/23 [==============================] - 10s 422ms/step - loss: 1.8360 - categorical_accuracy: 0.2319 - val_loss: 1.7370 - val_categorical_accuracy: 0.2500
#
# Epoch 00014: saving model to model_init_2020-03-3004_11_09.920829/model-00014-1.83602-0.23188-1.73704-0.25000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 15/30
# 23/23 [==============================] - 10s 421ms/step - loss: 1.7406 - categorical_accuracy: 0.2174 - val_loss: 1.7310 - val_categorical_accuracy: 0.2000
#
# Epoch 00015: saving model to model_init_2020-03-3004_11_09.920829/model-00015-1.74064-0.21739-1.73098-0.20000.h5
# Epoch 16/30
# 23/23 [==============================] - 10s 418ms/step - loss: 1.7393 - categorical_accuracy: 0.2705 - val_loss: 1.7627 - val_categorical_accuracy: 0.1750
#
# Epoch 00016: saving model to model_init_2020-03-3004_11_09.920829/model-00016-1.73928-0.27053-1.76272-0.17500.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 17/30
# 23/23 [==============================] - 10s 425ms/step - loss: 1.7670 - categorical_accuracy: 0.1884 - val_loss: 1.7176 - val_categorical_accuracy: 0.2000
#
# Epoch 00017: saving model to model_init_2020-03-3004_11_09.920829/model-00017-1.76700-0.18841-1.71756-0.20000.h5
# Epoch 18/30
# 23/23 [==============================] - 10s 421ms/step - loss: 1.9225 - categorical_accuracy: 0.1449 - val_loss: 1.7084 - val_categorical_accuracy: 0.2250
#
# Epoch 00018: saving model to model_init_2020-03-3004_11_09.920829/model-00018-1.92249-0.14493-1.70843-0.22500.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# Epoch 19/30
# 23/23 [==============================] - 10s 418ms/step - loss: 1.9099 - categorical_accuracy: 0.1836 - val_loss: 1.7120 - val_categorical_accuracy: 0.2000
#
# Epoch 00019: saving model to model_init_2020-03-3004_11_09.920829/model-00019-1.90995-0.18357-1.71200-0.20000.h5
# Epoch 20/30
# 23/23 [==============================] - 10s 427ms/step - loss: 1.8213 - categorical_accuracy: 0.2029 - val_loss: 1.8074 - val_categorical_accuracy: 0.1750
#
# Epoch 00020: saving model to model_init_2020-03-3004_11_09.920829/model-00020-1.82135-0.20290-1.80738-0.17500.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.
# Epoch 21/30
# 23/23 [==============================] - 10s 446ms/step - loss: 1.7812 - categorical_accuracy: 0.2174 - val_loss: 1.6844 - val_categorical_accuracy: 0.2250
#
# Epoch 00021: saving model to model_init_2020-03-3004_11_09.920829/model-00021-1.78116-0.21739-1.68438-0.22500.h5
# Epoch 22/30
# 23/23 [==============================] - 10s 424ms/step - loss: 1.8058 - categorical_accuracy: 0.1643 - val_loss: 1.8260 - val_categorical_accuracy: 0.1250
#
# Epoch 00022: saving model to model_init_2020-03-3004_11_09.920829/model-00022-1.80579-0.16425-1.82598-0.12500.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# Epoch 23/30
# 23/23 [==============================] - 10s 420ms/step - loss: 1.7289 - categorical_accuracy: 0.2077 - val_loss: 1.6270 - val_categorical_accuracy: 0.3250
#
# Epoch 00023: saving model to model_init_2020-03-3004_11_09.920829/model-00023-1.72889-0.20773-1.62699-0.32500.h5
# Epoch 24/30
# 23/23 [==============================] - 10s 422ms/step - loss: 1.7878 - categorical_accuracy: 0.1884 - val_loss: 1.7705 - val_categorical_accuracy: 0.1750
#
# Epoch 00024: saving model to model_init_2020-03-3004_11_09.920829/model-00024-1.78784-0.18841-1.77052-0.17500.h5
# Epoch 25/30
# 23/23 [==============================] - 10s 417ms/step - loss: 1.6974 - categorical_accuracy: 0.2319 - val_loss: 1.7399 - val_categorical_accuracy: 0.2000
#
# Epoch 00025: saving model to model_init_2020-03-3004_11_09.920829/model-00025-1.69735-0.23188-1.73993-0.20000.h5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 5.960464760645934e-11.
# Epoch 26/30
# 23/23 [==============================] - 10s 418ms/step - loss: 1.7395 - categorical_accuracy: 0.2077 - val_loss: 1.7314 - val_categorical_accuracy: 0.2000
#
# Epoch 00026: saving model to model_init_2020-03-3004_11_09.920829/model-00026-1.73953-0.20773-1.73144-0.20000.h5
# Epoch 27/30
# 23/23 [==============================] - 10s 435ms/step - loss: 1.7473 - categorical_accuracy: 0.2222 - val_loss: 1.6402 - val_categorical_accuracy: 0.3000
#
# Epoch 00027: saving model to model_init_2020-03-3004_11_09.920829/model-00027-1.74725-0.22222-1.64019-0.30000.h5
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.980232380322967e-11.
# Epoch 28/30
# 23/23 [==============================] - 10s 439ms/step - loss: 1.7521 - categorical_accuracy: 0.2174 - val_loss: 1.7746 - val_categorical_accuracy: 0.1750
#
# Epoch 00028: saving model to model_init_2020-03-3004_11_09.920829/model-00028-1.75211-0.21739-1.77464-0.17500.h5
# Epoch 29/30
# 23/23 [==============================] - 10s 421ms/step - loss: 1.7258 - categorical_accuracy: 0.2319 - val_loss: 1.7435 - val_categorical_accuracy: 0.2250
#
# Epoch 00029: saving model to model_init_2020-03-3004_11_09.920829/model-00029-1.72583-0.23188-1.74348-0.22500.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.4901161901614834e-11.
# Epoch 30/30
# 23/23 [==============================] - 10s 424ms/step - loss: 1.8284 - categorical_accuracy: 0.1836 - val_loss: 1.7309 - val_categorical_accuracy: 0.2250
#
# Epoch 00030: saving model to model_init_2020-03-3004_11_09.920829/model-00030-1.82837-0.18357-1.73085-0.22500.h5

# %%
batch_size = 50
num_epochs = 30

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# 14/14 [==============================] - 7s 535ms/step - loss: 1.8534 - categorical_accuracy: 0.1667 - val_loss: 1.6159 - val_categorical_accuracy: 0.2500
#
# Epoch 00001: saving model to model_init_2020-03-3004_11_09.920829/model-00001-1.85336-0.16667-1.61586-0.25000.h5
# Epoch 2/30
# 14/14 [==============================] - 6s 450ms/step - loss: 1.8048 - categorical_accuracy: 0.1667 - val_loss: 1.8943 - val_categorical_accuracy: 0.0500
#
# Epoch 00002: saving model to model_init_2020-03-3004_11_09.920829/model-00002-1.80476-0.16667-1.89434-0.05000.h5
# Epoch 3/30
# 14/14 [==============================] - 7s 478ms/step - loss: 1.8150 - categorical_accuracy: 0.1905 - val_loss: 1.7848 - val_categorical_accuracy: 0.2000
#
# Epoch 00003: saving model to model_init_2020-03-3004_11_09.920829/model-00003-1.81502-0.19048-1.78477-0.20000.h5
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 7.450580950807417e-12.
# Epoch 4/30
# 14/14 [==============================] - 6s 439ms/step - loss: 1.7985 - categorical_accuracy: 0.1825 - val_loss: 1.9044 - val_categorical_accuracy: 0.0000e+00
#
# Epoch 00004: saving model to model_init_2020-03-3004_11_09.920829/model-00004-1.79847-0.18254-1.90440-0.00000.h5
# Epoch 5/30
# 14/14 [==============================] - 7s 489ms/step - loss: 1.7187 - categorical_accuracy: 0.2143 - val_loss: 1.6811 - val_categorical_accuracy: 0.2000
#
# Epoch 00005: saving model to model_init_2020-03-3004_11_09.920829/model-00005-1.71873-0.21429-1.68106-0.20000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.725290475403709e-12.
# Epoch 6/30
# 14/14 [==============================] - 6s 455ms/step - loss: 1.8083 - categorical_accuracy: 0.1825 - val_loss: 1.5709 - val_categorical_accuracy: 0.3500
#
# Epoch 00006: saving model to model_init_2020-03-3004_11_09.920829/model-00006-1.80831-0.18254-1.57086-0.35000.h5
# Epoch 7/30
# 14/14 [==============================] - 6s 443ms/step - loss: 1.7541 - categorical_accuracy: 0.1825 - val_loss: 1.7156 - val_categorical_accuracy: 0.3000
#
# Epoch 00007: saving model to model_init_2020-03-3004_11_09.920829/model-00007-1.75415-0.18254-1.71563-0.30000.h5
# Epoch 8/30
# 14/14 [==============================] - 6s 433ms/step - loss: 1.7508 - categorical_accuracy: 0.2143 - val_loss: 1.7185 - val_categorical_accuracy: 0.2500
#
# Epoch 00008: saving model to model_init_2020-03-3004_11_09.920829/model-00008-1.75083-0.21429-1.71845-0.25000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.8626452377018543e-12.
# Epoch 9/30
# 14/14 [==============================] - 6s 419ms/step - loss: 1.7413 - categorical_accuracy: 0.2063 - val_loss: 1.7440 - val_categorical_accuracy: 0.1500
#
# Epoch 00009: saving model to model_init_2020-03-3004_11_09.920829/model-00009-1.74135-0.20635-1.74397-0.15000.h5
# Epoch 10/30
# 14/14 [==============================] - 6s 417ms/step - loss: 1.8014 - categorical_accuracy: 0.1984 - val_loss: 1.7264 - val_categorical_accuracy: 0.2500
#
# Epoch 00010: saving model to model_init_2020-03-3004_11_09.920829/model-00010-1.80140-0.19841-1.72635-0.25000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 9.313226188509272e-13.
# Epoch 11/30
# 14/14 [==============================] - 6s 438ms/step - loss: 1.8085 - categorical_accuracy: 0.1905 - val_loss: 1.6246 - val_categorical_accuracy: 0.2500
#
# Epoch 00011: saving model to model_init_2020-03-3004_11_09.920829/model-00011-1.80852-0.19048-1.62464-0.25000.h5
# Epoch 12/30
# 14/14 [==============================] - 6s 450ms/step - loss: 1.7520 - categorical_accuracy: 0.2937 - val_loss: 1.8433 - val_categorical_accuracy: 0.1500
#
# Epoch 00012: saving model to model_init_2020-03-3004_11_09.920829/model-00012-1.75199-0.29365-1.84332-0.15000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.656613094254636e-13.
# Epoch 13/30
# 14/14 [==============================] - 6s 445ms/step - loss: 1.7450 - categorical_accuracy: 0.2460 - val_loss: 1.7120 - val_categorical_accuracy: 0.2500
#
# Epoch 00013: saving model to model_init_2020-03-3004_11_09.920829/model-00013-1.74503-0.24603-1.71203-0.25000.h5
# Epoch 14/30
# 14/14 [==============================] - 6s 408ms/step - loss: 1.8011 - categorical_accuracy: 0.1587 - val_loss: 1.7390 - val_categorical_accuracy: 0.2000
#
# Epoch 00014: saving model to model_init_2020-03-3004_11_09.920829/model-00014-1.80108-0.15873-1.73898-0.20000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.328306547127318e-13.
# Epoch 15/30
# 14/14 [==============================] - 6s 430ms/step - loss: 1.7628 - categorical_accuracy: 0.2143 - val_loss: 1.7712 - val_categorical_accuracy: 0.2000
#
# Epoch 00015: saving model to model_init_2020-03-3004_11_09.920829/model-00015-1.76282-0.21429-1.77116-0.20000.h5
# Epoch 16/30
# 14/14 [==============================] - 6s 445ms/step - loss: 1.7098 - categorical_accuracy: 0.2619 - val_loss: 1.5951 - val_categorical_accuracy: 0.3000
#
# Epoch 00016: saving model to model_init_2020-03-3004_11_09.920829/model-00016-1.70985-0.26190-1.59511-0.30000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.164153273563659e-13.
# Epoch 17/30
# 14/14 [==============================] - 6s 451ms/step - loss: 1.7709 - categorical_accuracy: 0.1905 - val_loss: 1.8395 - val_categorical_accuracy: 0.1000
#
# Epoch 00017: saving model to model_init_2020-03-3004_11_09.920829/model-00017-1.77086-0.19048-1.83945-0.10000.h5
# Epoch 18/30
# 14/14 [==============================] - 6s 421ms/step - loss: 1.8255 - categorical_accuracy: 0.1746 - val_loss: 1.6968 - val_categorical_accuracy: 0.3000
#
# Epoch 00018: saving model to model_init_2020-03-3004_11_09.920829/model-00018-1.82545-0.17460-1.69683-0.30000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.820766367818295e-14.
# Epoch 19/30
# 14/14 [==============================] - 6s 436ms/step - loss: 1.7833 - categorical_accuracy: 0.1429 - val_loss: 1.6399 - val_categorical_accuracy: 0.3000
#
# Epoch 00019: saving model to model_init_2020-03-3004_11_09.920829/model-00019-1.78326-0.14286-1.63995-0.30000.h5
# Epoch 20/30
# 14/14 [==============================] - 6s 442ms/step - loss: 1.8038 - categorical_accuracy: 0.1984 - val_loss: 1.8031 - val_categorical_accuracy: 0.1500
#
# Epoch 00020: saving model to model_init_2020-03-3004_11_09.920829/model-00020-1.80377-0.19841-1.80308-0.15000.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.9103831839091474e-14.
# Epoch 21/30
# 14/14 [==============================] - 6s 453ms/step - loss: 1.8684 - categorical_accuracy: 0.1905 - val_loss: 1.7591 - val_categorical_accuracy: 0.2000
#
# Epoch 00021: saving model to model_init_2020-03-3004_11_09.920829/model-00021-1.86840-0.19048-1.75910-0.20000.h5
# Epoch 22/30
# 14/14 [==============================] - 6s 420ms/step - loss: 1.6615 - categorical_accuracy: 0.2460 - val_loss: 1.7578 - val_categorical_accuracy: 0.1000
#
# Epoch 00022: saving model to model_init_2020-03-3004_11_09.920829/model-00022-1.66148-0.24603-1.75777-0.10000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.4551915919545737e-14.
# Epoch 23/30
# 14/14 [==============================] - 6s 413ms/step - loss: 1.7354 - categorical_accuracy: 0.1905 - val_loss: 1.5378 - val_categorical_accuracy: 0.3000
#
# Epoch 00023: saving model to model_init_2020-03-3004_11_09.920829/model-00023-1.73536-0.19048-1.53783-0.30000.h5
# Epoch 24/30
# 14/14 [==============================] - 6s 441ms/step - loss: 1.7285 - categorical_accuracy: 0.1905 - val_loss: 1.6711 - val_categorical_accuracy: 0.2500
#
# Epoch 00024: saving model to model_init_2020-03-3004_11_09.920829/model-00024-1.72848-0.19048-1.67113-0.25000.h5
# Epoch 25/30
# 14/14 [==============================] - 7s 472ms/step - loss: 1.9353 - categorical_accuracy: 0.1111 - val_loss: 1.8720 - val_categorical_accuracy: 0.1500
#
# Epoch 00025: saving model to model_init_2020-03-3004_11_09.920829/model-00025-1.93527-0.11111-1.87204-0.15000.h5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 7.275957959772868e-15.
# Epoch 26/30
# 14/14 [==============================] - 6s 426ms/step - loss: 1.6691 - categorical_accuracy: 0.2460 - val_loss: 1.8312 - val_categorical_accuracy: 0.1000
#
# Epoch 00026: saving model to model_init_2020-03-3004_11_09.920829/model-00026-1.66914-0.24603-1.83118-0.10000.h5
# Epoch 27/30
# 14/14 [==============================] - 7s 483ms/step - loss: 1.8499 - categorical_accuracy: 0.1984 - val_loss: 1.7446 - val_categorical_accuracy: 0.2500
#
# Epoch 00027: saving model to model_init_2020-03-3004_11_09.920829/model-00027-1.84992-0.19841-1.74455-0.25000.h5
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.637978979886434e-15.
# Epoch 28/30
# 14/14 [==============================] - 6s 450ms/step - loss: 1.7707 - categorical_accuracy: 0.2143 - val_loss: 1.8519 - val_categorical_accuracy: 0.2000
#
# Epoch 00028: saving model to model_init_2020-03-3004_11_09.920829/model-00028-1.77070-0.21429-1.85192-0.20000.h5
# Epoch 29/30
# 14/14 [==============================] - 6s 425ms/step - loss: 1.7874 - categorical_accuracy: 0.2063 - val_loss: 1.8109 - val_categorical_accuracy: 0.1000
#
# Epoch 00029: saving model to model_init_2020-03-3004_11_09.920829/model-00029-1.78744-0.20635-1.81093-0.10000.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.818989489943217e-15.
# Epoch 30/30
# 14/14 [==============================] - 6s 439ms/step - loss: 1.7955 - categorical_accuracy: 0.2063 - val_loss: 1.6323 - val_categorical_accuracy: 0.3000
#
# Epoch 00030: saving model to model_init_2020-03-3004_11_09.920829/model-00030-1.79552-0.20635-1.63235-0.30000.h5

# %%
batch_size = 90
num_epochs = 30

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 4s 536ms/step - loss: 1.7178 - categorical_accuracy: 0.2361 - val_loss: 1.8077 - val_categorical_accuracy: 0.2000
#
# Epoch 00001: saving model to model_init_2020-03-3004_11_09.920829/model-00001-1.71781-0.23611-1.80772-0.20000.h5
# Epoch 2/30
# 8/8 [==============================] - 3s 437ms/step - loss: 1.7798 - categorical_accuracy: 0.2778 - val_loss: 1.6536 - val_categorical_accuracy: 0.2000
#
# Epoch 00002: saving model to model_init_2020-03-3004_11_09.920829/model-00002-1.77983-0.27778-1.65361-0.20000.h5
# Epoch 3/30
# 8/8 [==============================] - 4s 447ms/step - loss: 1.7269 - categorical_accuracy: 0.2500 - val_loss: 1.8391 - val_categorical_accuracy: 0.1000
#
# Epoch 00003: saving model to model_init_2020-03-3004_11_09.920829/model-00003-1.72691-0.25000-1.83915-0.10000.h5
# Epoch 4/30
# 8/8 [==============================] - 3s 433ms/step - loss: 1.8170 - categorical_accuracy: 0.1806 - val_loss: 1.5112 - val_categorical_accuracy: 0.4000
#
# Epoch 00004: saving model to model_init_2020-03-3004_11_09.920829/model-00004-1.81701-0.18056-1.51121-0.40000.h5
# Epoch 5/30
# 8/8 [==============================] - 4s 441ms/step - loss: 1.8122 - categorical_accuracy: 0.2222 - val_loss: 1.7575 - val_categorical_accuracy: 0.2000
#
# Epoch 00005: saving model to model_init_2020-03-3004_11_09.920829/model-00005-1.81222-0.22222-1.75754-0.20000.h5
# Epoch 6/30
# 8/8 [==============================] - 4s 451ms/step - loss: 1.8789 - categorical_accuracy: 0.1667 - val_loss: 1.6813 - val_categorical_accuracy: 0.2000
#
# Epoch 00006: saving model to model_init_2020-03-3004_11_09.920829/model-00006-1.87893-0.16667-1.68133-0.20000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.094947449716085e-16.
# Epoch 7/30
# 8/8 [==============================] - 4s 487ms/step - loss: 1.6451 - categorical_accuracy: 0.2917 - val_loss: 1.8092 - val_categorical_accuracy: 0.2000
#
# Epoch 00007: saving model to model_init_2020-03-3004_11_09.920829/model-00007-1.64514-0.29167-1.80925-0.20000.h5
# Epoch 8/30
# 8/8 [==============================] - 4s 455ms/step - loss: 1.8549 - categorical_accuracy: 0.1806 - val_loss: 1.7702 - val_categorical_accuracy: 0.1500
#
# Epoch 00008: saving model to model_init_2020-03-3004_11_09.920829/model-00008-1.85493-0.18056-1.77016-0.15000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 4.547473724858043e-16.
# Epoch 9/30
# 8/8 [==============================] - 4s 503ms/step - loss: 1.8348 - categorical_accuracy: 0.1528 - val_loss: 1.7578 - val_categorical_accuracy: 0.2000
#
# Epoch 00009: saving model to model_init_2020-03-3004_11_09.920829/model-00009-1.83484-0.15278-1.75782-0.20000.h5
# Epoch 10/30
# 8/8 [==============================] - 4s 472ms/step - loss: 1.7954 - categorical_accuracy: 0.1528 - val_loss: 1.7026 - val_categorical_accuracy: 0.2500
#
# Epoch 00010: saving model to model_init_2020-03-3004_11_09.920829/model-00010-1.79545-0.15278-1.70264-0.25000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 2.2737368624290214e-16.
# Epoch 11/30
# 8/8 [==============================] - 4s 464ms/step - loss: 1.8599 - categorical_accuracy: 0.2361 - val_loss: 1.9203 - val_categorical_accuracy: 0.1000
#
# Epoch 00011: saving model to model_init_2020-03-3004_11_09.920829/model-00011-1.85990-0.23611-1.92032-0.10000.h5
# Epoch 12/30
# 8/8 [==============================] - 4s 499ms/step - loss: 1.8822 - categorical_accuracy: 0.1528 - val_loss: 1.7197 - val_categorical_accuracy: 0.1500
#
# Epoch 00012: saving model to model_init_2020-03-3004_11_09.920829/model-00012-1.88223-0.15278-1.71969-0.15000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.1368684312145107e-16.
# Epoch 13/30
# 8/8 [==============================] - 4s 514ms/step - loss: 1.8891 - categorical_accuracy: 0.1806 - val_loss: 1.7061 - val_categorical_accuracy: 0.2000
#
# Epoch 00013: saving model to model_init_2020-03-3004_11_09.920829/model-00013-1.88907-0.18056-1.70614-0.20000.h5
# Epoch 14/30
# 8/8 [==============================] - 4s 452ms/step - loss: 1.8740 - categorical_accuracy: 0.1389 - val_loss: 1.7205 - val_categorical_accuracy: 0.2000
#
# Epoch 00014: saving model to model_init_2020-03-3004_11_09.920829/model-00014-1.87402-0.13889-1.72050-0.20000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 5.684342156072553e-17.
# Epoch 15/30
# 8/8 [==============================] - 4s 521ms/step - loss: 1.7589 - categorical_accuracy: 0.1528 - val_loss: 1.8044 - val_categorical_accuracy: 0.2000
#
# Epoch 00015: saving model to model_init_2020-03-3004_11_09.920829/model-00015-1.75892-0.15278-1.80439-0.20000.h5
# Epoch 16/30
# 8/8 [==============================] - 4s 468ms/step - loss: 1.8922 - categorical_accuracy: 0.1111 - val_loss: 1.7538 - val_categorical_accuracy: 0.2000
#
# Epoch 00016: saving model to model_init_2020-03-3004_11_09.920829/model-00016-1.89222-0.11111-1.75375-0.20000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 2.842171078036277e-17.
# Epoch 17/30
# 8/8 [==============================] - 4s 446ms/step - loss: 1.9236 - categorical_accuracy: 0.1667 - val_loss: 1.7188 - val_categorical_accuracy: 0.2500
#
# Epoch 00017: saving model to model_init_2020-03-3004_11_09.920829/model-00017-1.92363-0.16667-1.71880-0.25000.h5
# Epoch 18/30
# 8/8 [==============================] - 4s 492ms/step - loss: 1.8403 - categorical_accuracy: 0.1806 - val_loss: 1.5513 - val_categorical_accuracy: 0.3000
#
# Epoch 00018: saving model to model_init_2020-03-3004_11_09.920829/model-00018-1.84035-0.18056-1.55132-0.30000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.4210855390181384e-17.
# Epoch 19/30
# 8/8 [==============================] - 4s 448ms/step - loss: 1.7572 - categorical_accuracy: 0.1944 - val_loss: 1.6469 - val_categorical_accuracy: 0.3000
#
# Epoch 00019: saving model to model_init_2020-03-3004_11_09.920829/model-00019-1.75720-0.19444-1.64690-0.30000.h5
# Epoch 20/30
# 8/8 [==============================] - 4s 482ms/step - loss: 1.6157 - categorical_accuracy: 0.2500 - val_loss: 1.7523 - val_categorical_accuracy: 0.2500
#
# Epoch 00020: saving model to model_init_2020-03-3004_11_09.920829/model-00020-1.61575-0.25000-1.75228-0.25000.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 7.105427695090692e-18.
# Epoch 21/30
# 8/8 [==============================] - 4s 485ms/step - loss: 2.0586 - categorical_accuracy: 0.0694 - val_loss: 1.8110 - val_categorical_accuracy: 0.1000
#
# Epoch 00021: saving model to model_init_2020-03-3004_11_09.920829/model-00021-2.05864-0.06944-1.81095-0.10000.h5
# Epoch 22/30
# 8/8 [==============================] - 4s 440ms/step - loss: 1.7195 - categorical_accuracy: 0.1806 - val_loss: 1.6137 - val_categorical_accuracy: 0.3000
#
# Epoch 00022: saving model to model_init_2020-03-3004_11_09.920829/model-00022-1.71953-0.18056-1.61375-0.30000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 3.552713847545346e-18.
# Epoch 23/30
# 8/8 [==============================] - 4s 487ms/step - loss: 1.7874 - categorical_accuracy: 0.1944 - val_loss: 1.8294 - val_categorical_accuracy: 0.1500
#
# Epoch 00023: saving model to model_init_2020-03-3004_11_09.920829/model-00023-1.78738-0.19444-1.82942-0.15000.h5
# Epoch 24/30
# 8/8 [==============================] - 4s 445ms/step - loss: 1.8100 - categorical_accuracy: 0.1667 - val_loss: 1.8990 - val_categorical_accuracy: 0.1500
#
# Epoch 00024: saving model to model_init_2020-03-3004_11_09.920829/model-00024-1.80999-0.16667-1.89899-0.15000.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.776356923772673e-18.
# Epoch 25/30
# 8/8 [==============================] - 4s 448ms/step - loss: 1.8146 - categorical_accuracy: 0.1944 - val_loss: 1.7818 - val_categorical_accuracy: 0.1500
#
# Epoch 00025: saving model to model_init_2020-03-3004_11_09.920829/model-00025-1.81464-0.19444-1.78180-0.15000.h5
# Epoch 26/30
# 8/8 [==============================] - 4s 439ms/step - loss: 1.7046 - categorical_accuracy: 0.1667 - val_loss: 1.6075 - val_categorical_accuracy: 0.3500
#
# Epoch 00026: saving model to model_init_2020-03-3004_11_09.920829/model-00026-1.70460-0.16667-1.60753-0.35000.h5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 8.881784618863365e-19.
# Epoch 27/30
# 8/8 [==============================] - 4s 454ms/step - loss: 1.7810 - categorical_accuracy: 0.2222 - val_loss: 1.7908 - val_categorical_accuracy: 0.1000
#
# Epoch 00027: saving model to model_init_2020-03-3004_11_09.920829/model-00027-1.78104-0.22222-1.79079-0.10000.h5
# Epoch 28/30
# 8/8 [==============================] - 4s 502ms/step - loss: 1.7653 - categorical_accuracy: 0.1389 - val_loss: 1.6449 - val_categorical_accuracy: 0.2500
#
# Epoch 00028: saving model to model_init_2020-03-3004_11_09.920829/model-00028-1.76527-0.13889-1.64488-0.25000.h5
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.440892309431682e-19.
# Epoch 29/30
# 8/8 [==============================] - 4s 469ms/step - loss: 1.8181 - categorical_accuracy: 0.2222 - val_loss: 1.7513 - val_categorical_accuracy: 0.1500
#
# Epoch 00029: saving model to model_init_2020-03-3004_11_09.920829/model-00029-1.81811-0.22222-1.75133-0.15000.h5
# Epoch 30/30
# 8/8 [==============================] - 4s 439ms/step - loss: 1.7854 - categorical_accuracy: 0.1806 - val_loss: 1.7218 - val_categorical_accuracy: 0.2500
#
# Epoch 00030: saving model to model_init_2020-03-3004_11_09.920829/model-00030-1.78543-0.18056-1.72181-0.25000.h5
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.220446154715841e-19.

# %%
batch_size = 90
num_epochs = 20

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    

model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 4s 524ms/step - loss: 1.6439 - categorical_accuracy: 0.3056 - val_loss: 1.6510 - val_categorical_accuracy: 0.2500
#
# Epoch 00001: saving model to model_init_2020-03-3004_11_09.920829/model-00001-1.64385-0.30556-1.65102-0.25000.h5
# Epoch 2/20
# 8/8 [==============================] - 4s 442ms/step - loss: 1.7954 - categorical_accuracy: 0.2639 - val_loss: 1.6734 - val_categorical_accuracy: 0.2000
#
# Epoch 00002: saving model to model_init_2020-03-3004_11_09.920829/model-00002-1.79537-0.26389-1.67339-0.20000.h5
# Epoch 3/20
# 8/8 [==============================] - 4s 442ms/step - loss: 1.7181 - categorical_accuracy: 0.2361 - val_loss: 1.7377 - val_categorical_accuracy: 0.2000
#
# Epoch 00003: saving model to model_init_2020-03-3004_11_09.920829/model-00003-1.71812-0.23611-1.73766-0.20000.h5
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 1.1102230773579206e-19.
# Epoch 4/20
# 8/8 [==============================] - 4s 446ms/step - loss: 1.6960 - categorical_accuracy: 0.2639 - val_loss: 1.8446 - val_categorical_accuracy: 0.1500
#
# Epoch 00004: saving model to model_init_2020-03-3004_11_09.920829/model-00004-1.69601-0.26389-1.84458-0.15000.h5
# Epoch 5/20
# 8/8 [==============================] - 4s 483ms/step - loss: 1.7967 - categorical_accuracy: 0.1806 - val_loss: 1.7980 - val_categorical_accuracy: 0.2000
#
# Epoch 00005: saving model to model_init_2020-03-3004_11_09.920829/model-00005-1.79666-0.18056-1.79803-0.20000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 5.551115386789603e-20.
# Epoch 6/20
# 8/8 [==============================] - 4s 446ms/step - loss: 1.8265 - categorical_accuracy: 0.2222 - val_loss: 1.7175 - val_categorical_accuracy: 0.2000
#
# Epoch 00006: saving model to model_init_2020-03-3004_11_09.920829/model-00006-1.82652-0.22222-1.71754-0.20000.h5
# Epoch 7/20
# 8/8 [==============================] - 4s 442ms/step - loss: 1.8186 - categorical_accuracy: 0.1806 - val_loss: 1.5769 - val_categorical_accuracy: 0.3000
#
# Epoch 00007: saving model to model_init_2020-03-3004_11_09.920829/model-00007-1.81856-0.18056-1.57688-0.30000.h5
# Epoch 8/20
# 8/8 [==============================] - 4s 438ms/step - loss: 1.6722 - categorical_accuracy: 0.2639 - val_loss: 1.8333 - val_categorical_accuracy: 0.1500
#
# Epoch 00008: saving model to model_init_2020-03-3004_11_09.920829/model-00008-1.67218-0.26389-1.83334-0.15000.h5
# Epoch 9/20
# 8/8 [==============================] - 4s 454ms/step - loss: 1.8466 - categorical_accuracy: 0.1250 - val_loss: 1.7840 - val_categorical_accuracy: 0.2000
#
# Epoch 00009: saving model to model_init_2020-03-3004_11_09.920829/model-00009-1.84664-0.12500-1.78402-0.20000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 2.7755576933948015e-20.
# Epoch 10/20
# 8/8 [==============================] - 4s 490ms/step - loss: 1.7722 - categorical_accuracy: 0.2361 - val_loss: 1.7501 - val_categorical_accuracy: 0.2000
#
# Epoch 00010: saving model to model_init_2020-03-3004_11_09.920829/model-00010-1.77220-0.23611-1.75009-0.20000.h5
# Epoch 11/20
# 8/8 [==============================] - 4s 445ms/step - loss: 1.7755 - categorical_accuracy: 0.1944 - val_loss: 1.8050 - val_categorical_accuracy: 0.1000
#
# Epoch 00011: saving model to model_init_2020-03-3004_11_09.920829/model-00011-1.77553-0.19444-1.80502-0.10000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.3877788466974007e-20.
# Epoch 12/20
# 8/8 [==============================] - 4s 485ms/step - loss: 1.8376 - categorical_accuracy: 0.1667 - val_loss: 1.6312 - val_categorical_accuracy: 0.3000
#
# Epoch 00012: saving model to model_init_2020-03-3004_11_09.920829/model-00012-1.83758-0.16667-1.63122-0.30000.h5
# Epoch 13/20
# 8/8 [==============================] - 4s 445ms/step - loss: 1.8399 - categorical_accuracy: 0.1806 - val_loss: 1.7644 - val_categorical_accuracy: 0.2000
#
# Epoch 00013: saving model to model_init_2020-03-3004_11_09.920829/model-00013-1.83995-0.18056-1.76442-0.20000.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 6.938894233487004e-21.
# Epoch 14/20
# 8/8 [==============================] - 4s 465ms/step - loss: 1.8550 - categorical_accuracy: 0.1528 - val_loss: 1.6572 - val_categorical_accuracy: 0.3000
#
# Epoch 00014: saving model to model_init_2020-03-3004_11_09.920829/model-00014-1.85496-0.15278-1.65723-0.30000.h5
# Epoch 15/20
# 8/8 [==============================] - 4s 453ms/step - loss: 1.9106 - categorical_accuracy: 0.1528 - val_loss: 1.6305 - val_categorical_accuracy: 0.2500
#
# Epoch 00015: saving model to model_init_2020-03-3004_11_09.920829/model-00015-1.91055-0.15278-1.63046-0.25000.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 3.469447116743502e-21.
# Epoch 16/20
# 8/8 [==============================] - 4s 443ms/step - loss: 1.7672 - categorical_accuracy: 0.2222 - val_loss: 1.8456 - val_categorical_accuracy: 0.1500
#
# Epoch 00016: saving model to model_init_2020-03-3004_11_09.920829/model-00016-1.76722-0.22222-1.84562-0.15000.h5
# Epoch 17/20
# 8/8 [==============================] - 4s 446ms/step - loss: 1.8039 - categorical_accuracy: 0.2500 - val_loss: 1.6132 - val_categorical_accuracy: 0.3000
#
# Epoch 00017: saving model to model_init_2020-03-3004_11_09.920829/model-00017-1.80388-0.25000-1.61321-0.30000.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.734723558371751e-21.
# Epoch 18/20
# 8/8 [==============================] - 4s 466ms/step - loss: 1.8338 - categorical_accuracy: 0.1667 - val_loss: 1.7751 - val_categorical_accuracy: 0.1500
#
# Epoch 00018: saving model to model_init_2020-03-3004_11_09.920829/model-00018-1.83380-0.16667-1.77510-0.15000.h5
# Epoch 19/20
# 8/8 [==============================] - 4s 458ms/step - loss: 1.7733 - categorical_accuracy: 0.2361 - val_loss: 1.6493 - val_categorical_accuracy: 0.3000
#
# Epoch 00019: saving model to model_init_2020-03-3004_11_09.920829/model-00019-1.77331-0.23611-1.64931-0.30000.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 8.673617791858755e-22.
# Epoch 20/20
# 8/8 [==============================] - 4s 444ms/step - loss: 1.8496 - categorical_accuracy: 0.2222 - val_loss: 1.7768 - val_categorical_accuracy: 0.2000
#
# Epoch 00020: saving model to model_init_2020-03-3004_11_09.920829/model-00020-1.84961-0.22222-1.77684-0.20000.h5
